# %%
with open('crop_growth_report.txt', 'r') as file:
    print(file.read())
# Out:
# Crop Growth Stage Report
# -------------------------
# Current Day After Sowing: 30
#
# Current Stage: Vegetative
# Days Remaining in this stage: 15
#
# NEW CROP GROWTH UPDATE
# ----------------------
# Day After Sowing: 3
# Stage: Germination
# Days Remaining in Stage: 4
#
# Day After Sowing: 10
# Stage: Seedling
# Days Remaining in Stage: 11
#
# Day After Sowing: 30
# Stage: Vegetative
# Days Remaining in Stage: 15
#
# Day After Sowing: 50
# Stage: Flowering
# Days Remaining in Stage: 15
#
# Day After Sowing: 75
# Stage: Grain Filling
# Days Remaining in Stage: 10
#
# Day After Sowing: 90
# Stage: Maturity
# Status: Crop has reached maturity
#
#
# NEW CROP GROWTH UPDATE
# ----------------------
# Day After Sowing: 3
# Stage: Germination
# Days Remaining in Stage: 4
#
# Day After Sowing: 10
# Stage: Seedling
# Days Remaining in Stage: 11
#
# Day After Sowing: 30
# Stage: Vegetative
# Days Remaining in Stage: 15
#
# Day After Sowing: 50
# Stage: Flowering
# ...
