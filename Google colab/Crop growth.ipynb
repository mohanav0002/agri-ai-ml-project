# %%
with open("crop_growth_status.txt", "r") as file:
      print(file.read())
# Out:
# Crop Growth Stage Tracking Report
# ---------------------------------
# Current Day After Sowing: 90
#
# Current Stage: Maturity
# Crop has reached full maturity.
#
# Daily Growth Status:
# Day 0: Germination
# Day 1: Germination
# Day 2: Germination
# Day 3: Germination
# Day 4: Germination
# Day 5: Germination
# Day 6: Germination
# Day 7: Germination
# Day 8: Seedling
# Day 9: Seedling
# Day 10: Seedling
# Day 11: Seedling
# Day 12: Seedling
# Day 13: Seedling
# Day 14: Seedling
# Day 15: Seedling
# Day 16: Seedling
# Day 17: Seedling
# Day 18: Seedling
# Day 19: Seedling
# Day 20: Seedling
# Day 21: Seedling
# Day 22: Vegetative
# Day 23: Vegetative
# Day 24: Vegetative
# Day 25: Vegetative
# Day 26: Vegetative
# Day 27: Vegetative
# Day 28: Vegetative
# Day 29: Vegetative
# Day 30: Vegetative
# Day 31: Vegetative
# Day 32: Vegetative
# Day 33: Vegetative
# Day 34: Vegetative
# Day 35: Vegetative
# Day 36: Vegetative
# Day 37: Vegetative
# Day 38: Vegetative
# Day 39: Vegetative
# ...
