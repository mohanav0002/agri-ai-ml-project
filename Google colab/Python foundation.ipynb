# %%
a = 12
b = 3
print(a + b)
print(a / b)
print(a % b)
print(a ** b)
# Out:
# 15
# 4.0
# 0
# 1728

# %%
age = 18
print(age >= 18)
# Out:
# True

# %%
marks = 75
attendance = True
result = marks > 60 and attendance
print(result) # TrueTrue
# Out:
# True

# %%
x = 5
print(-x)
print(--x)
# Out:
# -5
# 5

# %%
marks = 75
attendance = True
result = marks > 60 and attendance
print(marks)
# Out:
# 75

# %%
marks = 75
attendance = True
result = marks > 60 and attendance
print(result)
# Out:
# True

# %%
fruits = ["apple", "banana", "orange"]
print("banana" in fruits)
print("grape" in fruits)
# Out:
# True
# False

# %%
a = 10
b = 10
print(a is b)
# Out:
# True

# %%
x = [1, 2, 3]
y = [1, 2, 3]
print(x is y)
# Out:
# False

# %%
colors = ["red", "blue", "green"]
print("yellow" not in colors) # True
print("red" not in colors) # False
# Out:
# True
# False

# %%
result = 10 + 2 * 3
print(result)
# Out:
# 16

# %%
result = (10 + 2) * 3
print(result)
# Out:
# 36

# %%
num = 8
# Break it down:
# Condition 1: Is num positive?
is_positive = num > 0
# Condition 2: Is num even?
is_even = num % 2 == 0
# Combine both conditions
result = is_positive and is_even
print(result)
# Out:
# True
